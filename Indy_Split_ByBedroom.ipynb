# %%
import csv
import pandas as pd
indy_predicted_df = pd.read_csv('Indianapolis_Predicted_Data.csv')
indy_predicted_df.head()
# Out:
#    Unnamed: 0  Integer_Year  Median List Price Calculated  \
# 0           0            25                 189473.018375
# 1           1            25                 192833.784967
# 2           2            25                 192778.387716
# 3           3            25                 193129.236975
# 4           4            25                 191079.538669
#
#    Median List Price per SqFt Calculated  Median Market Value (Single Family)  \
# 0                             130.178332                        202641.007899
# 1                             133.004470                        204674.278603
# 2                             132.684530                        204424.325703
# 3                             132.844500                        204496.427501
# 4                             130.871536                        203501.422688
#
#    46214  46219  46220  46227  1 Bedroom  ...  February  January  July  June  \
# ...

# %%
indy_predicted_dedummied_df = pd.wide_to_long(indy_predicted_df, stubnames='462', i = ['Median List Price Calculated',
                                                                                      'Median List Price per SqFt Calculated',
                                                                                      'Median Market Value (Single Family)',
                                                                                      'Median Bedroom Price'],
                                             j = 'ZipCode')

# %%
indy_predicted_dedummied_df
# Out:
#                                                                                                                                      June  \
# Median List Price Calculated Median List Price per SqFt Calculated Median Market Value (Single Family) Median Bedroom Price ZipCode
# 189473.018375                130.178332                            202641.007899                       134363.45            14          0
#                                                                                                                             19          0
#                                                                                                                             20          0
#                                                                                                                             27          0
# 192833.784967                133.004470                            204674.278603                       182293.23            14          0
# ...
