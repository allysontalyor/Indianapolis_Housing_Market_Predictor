# %%
import pandas as pd

# %%
February_46220_Complete = pd.read_csv("February_46220_Complete.csv")
February_46219_Complete = pd.read_csv("February_46219_Complete.csv")
February_46227_Complete = pd.read_csv("February_46227_Complete.csv")

# %%
February_46220_Complete["Zip_Code_Integer"] = 1
February_46220_Complete["Integer_Year"] = February_46220_Complete["Year"] - 1995
February_46220_Complete.head()
# Out:
#    Unnamed: 0  Zip_Code        Date  Year  Year_Integer  Month  \
# 0        1118     46220  1997-02-28  1997             1      2
# 1        1130     46220  1998-02-28  1998             2      2
# 2        1142     46220  1999-02-28  1999             3      2
# 3        1154     46220  2000-02-29  2000             4      2
# 4        1166     46220  2001-02-28  2001             5      2
#
#    Median Market Value (Single Family)  Median Price 1 Bedroom  \
# 0                             127200.0                113100.0
# 1                             153100.0                118700.0
# 2                             148500.0                122400.0
# 3                             155199.0                 97118.0
# 4                             155226.0                 96610.0
#
#    Median Price 2 Bedroom  Median Price 3 Bedroom  Median Price 4 Bedroom  \
# 0                116700.0                129900.0                170400.0
# ...

# %%
February_46220_OneBedroom = February_46220_Complete[["Date", "Year", "Integer_Year", "Month", "Zip_Code",
                                                     "Zip_Code_Integer",
                                                     "Median Price 1 Bedroom",
                                                     "Median Market Value (Single Family)",
                                                     "Median List Price per SqFt Calculated",
                                                     "Median List Price Calculated"]]

February_46220_OneBedroom["No. of Bedrooms"] = 1
February_46220_OneBedroom = February_46220_OneBedroom.rename(columns={"Median Price 1 Bedroom": "Median Bedroom Price"})
February_46220_OneBedroom.head()
# Out:
# /Users/allysontalyor/Applications/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          Date  Year  Integer_Year  Month  Zip_Code  Zip_Code_Integer  \
# 0  1997-02-28  1997             2      2     46220                 1
# 1  1998-02-28  1998             3      2     46220                 1
# 2  1999-02-28  1999             4      2     46220                 1
# 3  2000-02-29  2000             5      2     46220                 1
# 4  2001-02-28  2001             6      2     46220                 1
#
#    Median Bedroom Price  Median Market Value (Single Family)  \
# 0              113100.0                             127200.0
# ...

# %%
February_46220_TwoBedroom = February_46220_Complete[["Date", "Year", "Integer_Year", "Month", "Zip_Code",
                                                     "Zip_Code_Integer",
                                                     "Median Price 2 Bedroom",
                                                     "Median Market Value (Single Family)",
                                                     "Median List Price per SqFt Calculated",
                                                     "Median List Price Calculated"]]

February_46220_TwoBedroom["No. of Bedrooms"] = 2
February_46220_TwoBedroom = February_46220_TwoBedroom.rename(columns={"Median Price 2 Bedroom": "Median Bedroom Price"})
February_46220_TwoBedroom.head()
# Out:
# /Users/allysontalyor/Applications/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          Date  Year  Integer_Year  Month  Zip_Code  Zip_Code_Integer  \
# 0  1997-02-28  1997             2      2     46220                 1
# 1  1998-02-28  1998             3      2     46220                 1
# 2  1999-02-28  1999             4      2     46220                 1
# 3  2000-02-29  2000             5      2     46220                 1
# 4  2001-02-28  2001             6      2     46220                 1
#
#    Median Bedroom Price  Median Market Value (Single Family)  \
# 0              116700.0                             127200.0
# ...

# %%
February_46220_ThreeBedroom = February_46220_Complete[["Date", "Year", "Integer_Year", "Month", "Zip_Code",
                                                     "Zip_Code_Integer",
                                                     "Median Price 3 Bedroom",
                                                     "Median Market Value (Single Family)",
                                                     "Median List Price per SqFt Calculated",
                                                     "Median List Price Calculated"]]

February_46220_ThreeBedroom["No. of Bedrooms"] = 3
February_46220_ThreeBedroom = February_46220_ThreeBedroom.rename(columns={"Median Price 3 Bedroom": "Median Bedroom Price"})
February_46220_ThreeBedroom.head()
# Out:
# /Users/allysontalyor/Applications/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          Date  Year  Integer_Year  Month  Zip_Code  Zip_Code_Integer  \
# 0  1997-02-28  1997             2      2     46220                 1
# 1  1998-02-28  1998             3      2     46220                 1
# 2  1999-02-28  1999             4      2     46220                 1
# 3  2000-02-29  2000             5      2     46220                 1
# 4  2001-02-28  2001             6      2     46220                 1
#
#    Median Bedroom Price  Median Market Value (Single Family)  \
# 0              129900.0                             127200.0
# ...

# %%
February_46220_FourBedroom = February_46220_Complete[["Date", "Year", "Integer_Year", "Month", "Zip_Code",
                                                     "Zip_Code_Integer",
                                                     "Median Price 4 Bedroom",
                                                     "Median Market Value (Single Family)",
                                                     "Median List Price per SqFt Calculated",
                                                     "Median List Price Calculated"]]

February_46220_FourBedroom["No. of Bedrooms"] = 4
February_46220_FourBedroom = February_46220_FourBedroom.rename(columns={"Median Price 4 Bedroom": "Median Bedroom Price"})
February_46220_FourBedroom.head()
# Out:
# /Users/allysontalyor/Applications/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          Date  Year  Integer_Year  Month  Zip_Code  Zip_Code_Integer  \
# 0  1997-02-28  1997             2      2     46220                 1
# 1  1998-02-28  1998             3      2     46220                 1
# 2  1999-02-28  1999             4      2     46220                 1
# 3  2000-02-29  2000             5      2     46220                 1
# 4  2001-02-28  2001             6      2     46220                 1
#
#    Median Bedroom Price  Median Market Value (Single Family)  \
# 0              170400.0                             127200.0
# ...

# %%
February_46220_FiveBedroom = February_46220_Complete[["Date", "Year", "Integer_Year", "Month", "Zip_Code",
                                                     "Zip_Code_Integer",
                                                     "Median Price 5 Bedroom",
                                                     "Median Market Value (Single Family)",
                                                     "Median List Price per SqFt Calculated",
                                                     "Median List Price Calculated"]]

February_46220_FiveBedroom["No. of Bedrooms"] = 5
February_46220_FiveBedroom = February_46220_FiveBedroom.rename(columns={"Median Price 5 Bedroom": "Median Bedroom Price"})
February_46220_FiveBedroom.head()
# Out:
# /Users/allysontalyor/Applications/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          Date  Year  Integer_Year  Month  Zip_Code  Zip_Code_Integer  \
# 0  1997-02-28  1997             2      2     46220                 1
# 1  1998-02-28  1998             3      2     46220                 1
# 2  1999-02-28  1999             4      2     46220                 1
# 3  2000-02-29  2000             5      2     46220                 1
# 4  2001-02-28  2001             6      2     46220                 1
#
#    Median Bedroom Price  Median Market Value (Single Family)  \
# 0              253600.0                             127200.0
# ...

# %%
February_46220_Final = pd.concat([February_46220_FiveBedroom, 
                                  February_46220_FourBedroom, 
                                  February_46220_ThreeBedroom,
                                  February_46220_TwoBedroom,
                                  February_46220_OneBedroom])

# %%
February_46220_Final.to_csv("February_46220_Final.csv")

# %%
February_46219_Complete["Zip_Code_Integer"] = 2
February_46219_Complete["Integer_Year"] = February_46219_Complete["Year"] - 1995
February_46219_Complete.head()
# Out:
#    Unnamed: 0  Zip_Code        Date  Year  Year_Integer  Month  \
# 0         830     46219  1997-02-28  1997             1      2
# 1         842     46219  1998-02-28  1998             2      2
# 2         854     46219  1999-02-28  1999             3      2
# 3         866     46219  2000-02-29  2000             4      2
# 4         878     46219  2001-02-28  2001             5      2
#
#    Median Market Value (Single Family)  Median Price 1 Bedroom  \
# 0                              82100.0                     NaN
# 1                              81100.0                     NaN
# 2                              89300.0                     NaN
# 3                              76556.0                 58678.0
# 4                              75694.0                 56695.0
#
#    Median Price 2 Bedroom  Median Price 3 Bedroom  Median Price 4 Bedroom  \
# 0                 77300.0                 85500.0                115700.0
# ...

# %%
February_46219_OneBedroom = February_46219_Complete[["Date", "Year", "Integer_Year", "Month", "Zip_Code",
                                                     "Zip_Code_Integer",
                                                     "Median Price 1 Bedroom",
                                                     "Median Market Value (Single Family)",
                                                     "Median List Price per SqFt Calculated",
                                                     "Median List Price Calculated"]]

February_46219_OneBedroom["No. of Bedrooms"] = 1
February_46219_OneBedroom = February_46219_OneBedroom.rename(columns={"Median Price 1 Bedroom": "Median Bedroom Price"})
February_46219_OneBedroom = February_46219_OneBedroom.dropna()
#February_46219_OneBedroom.head()
# Out:
# /Users/allysontalyor/Applications/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
February_46219_TwoBedroom = February_46219_Complete[["Date", "Year", "Integer_Year", "Month", "Zip_Code",
                                                     "Zip_Code_Integer",
                                                     "Median Price 2 Bedroom",
                                                     "Median Market Value (Single Family)",
                                                     "Median List Price per SqFt Calculated",
                                                     "Median List Price Calculated"]]

February_46219_TwoBedroom["No. of Bedrooms"] = 2
February_46219_TwoBedroom = February_46219_TwoBedroom.rename(columns={"Median Price 2 Bedroom": "Median Bedroom Price"})
February_46219_TwoBedroom = February_46219_TwoBedroom.dropna()
#February_46219_TwoBedroom.head()
# Out:
# /Users/allysontalyor/Applications/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
February_46219_ThreeBedroom = February_46219_Complete[["Date", "Year", "Integer_Year", "Month", "Zip_Code",
                                                     "Zip_Code_Integer",
                                                     "Median Price 3 Bedroom",
                                                     "Median Market Value (Single Family)",
                                                     "Median List Price per SqFt Calculated",
                                                     "Median List Price Calculated"]]

February_46219_ThreeBedroom["No. of Bedrooms"] = 3
February_46219_ThreeBedroom = February_46219_ThreeBedroom.rename(columns={"Median Price 3 Bedroom": "Median Bedroom Price"})
February_46219_ThreeBedroom = February_46219_ThreeBedroom.dropna()
#February_46219_ThreeBedroom.head()
# Out:
# /Users/allysontalyor/Applications/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
February_46219_FourBedroom = February_46219_Complete[["Date", "Year", "Integer_Year", "Month", "Zip_Code",
                                                     "Zip_Code_Integer",
                                                     "Median Price 4 Bedroom",
                                                     "Median Market Value (Single Family)",
                                                     "Median List Price per SqFt Calculated",
                                                     "Median List Price Calculated"]]

February_46219_FourBedroom["No. of Bedrooms"] = 4
February_46219_FourBedroom = February_46219_FourBedroom.rename(columns={"Median Price 4 Bedroom": "Median Bedroom Price"})
February_46219_FourBedroom = February_46219_FourBedroom.dropna()
#February_46219_FourBedroom.head()
# Out:
# /Users/allysontalyor/Applications/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
February_46219_FiveBedroom = February_46219_Complete[["Date", "Year", "Integer_Year", "Month", "Zip_Code",
                                                     "Zip_Code_Integer",
                                                     "Median Price 5 Bedroom",
                                                     "Median Market Value (Single Family)",
                                                     "Median List Price per SqFt Calculated",
                                                     "Median List Price Calculated"]]

February_46219_FiveBedroom["No. of Bedrooms"] = 5
February_46219_FiveBedroom = February_46219_FiveBedroom.rename(columns={"Median Price 5 Bedroom": "Median Bedroom Price"})
February_46219_FiveBedroom = February_46219_FiveBedroom.dropna()
#February_46219_FiveBedroom.head()
# Out:
# /Users/allysontalyor/Applications/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
February_46219_Final = pd.concat([February_46219_FiveBedroom, 
                                  February_46219_FourBedroom, 
                                  February_46219_ThreeBedroom,
                                  February_46219_TwoBedroom,
                                  February_46219_OneBedroom])

# %%
February_46219_Final.to_csv("February_46219_Final.csv")

# %%
February_46227_Complete["Zip_Code_Integer"] = 3
February_46227_Complete["Integer_Year"] = February_46220_Complete["Year"] - 1995
February_46227_Complete.head()
# Out:
#    Unnamed: 0  Zip_Code        Date  Year  Year_Integer  Month  \
# 0        2756     46227  1997-02-28  1997             1      2
# 1        2768     46227  1998-02-28  1998             2      2
# 2        2780     46227  1999-02-28  1999             3      2
# 3        2792     46227  2000-02-29  2000             4      2
# 4        2804     46227  2001-02-28  2001             5      2
#
#    Median Market Value (Single Family)  Median Price 1 Bedroom  \
# 0                              86600.0                 70200.0
# 1                              91600.0                 67300.0
# 2                             101100.0                 67600.0
# 3                              85081.0                 54144.0
# 4                              93984.0                 48712.0
#
#    Median Price 2 Bedroom  Median Price 3 Bedroom  Median Price 4 Bedroom  \
# 0                 75100.0                 87800.0                123100.0
# ...

# %%
February_46227_OneBedroom = February_46227_Complete[["Date", "Year", "Integer_Year", "Month", "Zip_Code",
                                                     "Zip_Code_Integer",
                                                     "Median Price 1 Bedroom",
                                                     "Median Market Value (Single Family)",
                                                     "Median List Price per SqFt Calculated",
                                                     "Median List Price Calculated"]]

February_46227_OneBedroom["No. of Bedrooms"] = 1
February_46227_OneBedroom = February_46227_OneBedroom.rename(columns={"Median Price 1 Bedroom": "Median Bedroom Price"})
February_46227_OneBedroom = February_46227_OneBedroom.dropna()
February_46227_OneBedroom.head()
# Out:
# /Users/allysontalyor/Applications/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          Date  Year  Integer_Year  Month  Zip_Code  Zip_Code_Integer  \
# 0  1997-02-28  1997             2      2     46227                 3
# 1  1998-02-28  1998             3      2     46227                 3
# 2  1999-02-28  1999             4      2     46227                 3
# 3  2000-02-29  2000             5      2     46227                 3
# 4  2001-02-28  2001             6      2     46227                 3
#
#    Median Bedroom Price  Median Market Value (Single Family)  \
# 0               70200.0                              86600.0
# ...

# %%
February_46227_TwoBedroom = February_46227_Complete[["Date", "Year", "Integer_Year", "Month", "Zip_Code",
                                                     "Zip_Code_Integer",
                                                     "Median Price 2 Bedroom",
                                                     "Median Market Value (Single Family)",
                                                     "Median List Price per SqFt Calculated",
                                                     "Median List Price Calculated"]]

February_46227_TwoBedroom["No. of Bedrooms"] = 2
February_46227_TwoBedroom = February_46227_TwoBedroom.rename(columns={"Median Price 2 Bedroom": "Median Bedroom Price"})
February_46227_TwoBedroom = February_46227_TwoBedroom.dropna()
February_46227_TwoBedroom.head()
# Out:
# /Users/allysontalyor/Applications/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          Date  Year  Integer_Year  Month  Zip_Code  Zip_Code_Integer  \
# 0  1997-02-28  1997             2      2     46227                 3
# 1  1998-02-28  1998             3      2     46227                 3
# 2  1999-02-28  1999             4      2     46227                 3
# 3  2000-02-29  2000             5      2     46227                 3
# 4  2001-02-28  2001             6      2     46227                 3
#
#    Median Bedroom Price  Median Market Value (Single Family)  \
# 0               75100.0                              86600.0
# ...

# %%
February_46227_ThreeBedroom = February_46227_Complete[["Date", "Year", "Integer_Year", "Month", "Zip_Code",
                                                     "Zip_Code_Integer",
                                                     "Median Price 3 Bedroom",
                                                     "Median Market Value (Single Family)",
                                                     "Median List Price per SqFt Calculated",
                                                     "Median List Price Calculated"]]

February_46227_ThreeBedroom["No. of Bedrooms"] = 3
February_46227_ThreeBedroom = February_46227_ThreeBedroom.rename(columns={"Median Price 3 Bedroom": "Median Bedroom Price"})
February_46227_ThreeBedroom = February_46227_ThreeBedroom.dropna()
February_46227_ThreeBedroom.head()
# Out:
# /Users/allysontalyor/Applications/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          Date  Year  Integer_Year  Month  Zip_Code  Zip_Code_Integer  \
# 0  1997-02-28  1997             2      2     46227                 3
# 1  1998-02-28  1998             3      2     46227                 3
# 2  1999-02-28  1999             4      2     46227                 3
# 3  2000-02-29  2000             5      2     46227                 3
# 4  2001-02-28  2001             6      2     46227                 3
#
#    Median Bedroom Price  Median Market Value (Single Family)  \
# 0               87800.0                              86600.0
# ...

# %%
February_46227_FourBedroom = February_46227_Complete[["Date", "Year", "Integer_Year", "Month", "Zip_Code",
                                                     "Zip_Code_Integer",
                                                     "Median Price 4 Bedroom",
                                                     "Median Market Value (Single Family)",
                                                     "Median List Price per SqFt Calculated",
                                                     "Median List Price Calculated"]]

February_46227_FourBedroom["No. of Bedrooms"] = 4
February_46227_FourBedroom = February_46227_FourBedroom.rename(columns={"Median Price 4 Bedroom": "Median Bedroom Price"})
February_46227_FourBedroom = February_46227_FourBedroom.dropna()
February_46227_FourBedroom.head()
# Out:
# /Users/allysontalyor/Applications/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          Date  Year  Integer_Year  Month  Zip_Code  Zip_Code_Integer  \
# 0  1997-02-28  1997             2      2     46227                 3
# 1  1998-02-28  1998             3      2     46227                 3
# 2  1999-02-28  1999             4      2     46227                 3
# 3  2000-02-29  2000             5      2     46227                 3
# 4  2001-02-28  2001             6      2     46227                 3
#
#    Median Bedroom Price  Median Market Value (Single Family)  \
# 0              123100.0                              86600.0
# ...

# %%
February_46227_FiveBedroom = February_46227_Complete[["Date", "Year", "Integer_Year", "Month", "Zip_Code",
                                                     "Zip_Code_Integer",
                                                     "Median Price 5 Bedroom",
                                                     "Median Market Value (Single Family)",
                                                     "Median List Price per SqFt Calculated",
                                                     "Median List Price Calculated"]]

February_46227_FiveBedroom["No. of Bedrooms"] = 5
February_46227_FiveBedroom = February_46227_FiveBedroom.rename(columns={"Median Price 5 Bedroom": "Median Bedroom Price"})
February_46227_FiveBedroom = February_46227_FiveBedroom.dropna()
February_46227_FiveBedroom.head()
# Out:
# /Users/allysontalyor/Applications/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          Date  Year  Integer_Year  Month  Zip_Code  Zip_Code_Integer  \
# 4  2001-02-28  2001             6      2     46227                 3
# 5  2002-02-28  2002             7      2     46227                 3
# 6  2003-02-28  2003             8      2     46227                 3
# 7  2004-02-29  2004             9      2     46227                 3
# 8  2005-02-28  2005            10      2     46227                 3
#
#    Median Bedroom Price  Median Market Value (Single Family)  \
# 4              141957.0                              93984.0
# ...

# %%
February_46227_Final = pd.concat([February_46227_FiveBedroom, 
                                  February_46227_FourBedroom, 
                                  February_46227_ThreeBedroom,
                                  February_46227_TwoBedroom,
                                  February_46227_OneBedroom])

# %%
February_46227_Final
# Out:
#           Date  Year  Integer_Year  Month  Zip_Code  Zip_Code_Integer  \
# 4   2001-02-28  2001             6      2     46227                 3
# 5   2002-02-28  2002             7      2     46227                 3
# 6   2003-02-28  2003             8      2     46227                 3
# 7   2004-02-29  2004             9      2     46227                 3
# 8   2005-02-28  2005            10      2     46227                 3
# ..         ...   ...           ...    ...       ...               ...
# 19  2016-02-29  2016            21      2     46227                 3
# 20  2017-02-28  2017            22      2     46227                 3
# 21  2018-02-28  2018            23      2     46227                 3
# 22  2019-02-28  2019            24      2     46227                 3
# 23  2020-02-29  2020            25      2     46227                 3
#
#     Median Bedroom Price  Median Market Value (Single Family)  \
# 4               141957.0                              93984.0
# ...

# %%
February_46227_Final.to_csv("February_46227_Final.csv")

# %%
Indianapolis_Housing_February = pd.concat([February_46220_Final, February_46219_Final, February_46227_Final])

# %%
Indianapolis_Housing_February
# Out:
#           Date  Year  Integer_Year  Month  Zip_Code  Zip_Code_Integer  \
# 0   1997-02-28  1997             2      2     46220                 1
# 1   1998-02-28  1998             3      2     46220                 1
# 2   1999-02-28  1999             4      2     46220                 1
# 3   2000-02-29  2000             5      2     46220                 1
# 4   2001-02-28  2001             6      2     46220                 1
# ..         ...   ...           ...    ...       ...               ...
# 19  2016-02-29  2016            21      2     46227                 3
# 20  2017-02-28  2017            22      2     46227                 3
# 21  2018-02-28  2018            23      2     46227                 3
# 22  2019-02-28  2019            24      2     46227                 3
# 23  2020-02-29  2020            25      2     46227                 3
#
#     Median Bedroom Price  Median Market Value (Single Family)  \
# 0               253600.0                             127200.0
# ...

# %%
Indianapolis_Housing_February.to_csv("Indianapolis_Housing_February.csv")
