# %%
# Dependencies
import numpy as np
import quandl
import pandas as pd
import json
import requests

# %%
quandl.ApiConfig.api_key = "vyjz35TZgRa_whhfdpg2"

# %%
#Practice for one zip code - 46220
zip_46220_1B = quandl.get("ZILLOW/Z46220_ZHVI1B")
zip_46220_1B_df = pd.DataFrame(zip_46220_1B)
zip_46220_1B_df1 = zip_46220_1B_df.rename(columns={"Value":"Median Price 1 Bedroom"})
zip_46220_1B_df1.tail()
# Out:
#             Median Price 1 Bedroom
# Date
# 2019-11-30                172591.0
# 2019-12-31                172684.0
# 2020-01-31                173191.0
# 2020-02-29                174423.0
# 2020-03-31                175273.0

# %%
zip_46220_2B = quandl.get("ZILLOW/Z46220_ZHVI2B")
zip_46220_2B_df = pd.DataFrame(zip_46220_2B)
zip_46220_2B_df1 = zip_46220_2B_df.rename(columns={"Value":"Median Price 2 Bedrooms"})
zip_46220_2B_df1.tail()
# Out:
#             Median Price 2 Bedrooms
# Date
# 2019-11-30                 215522.0
# 2019-12-31                 215573.0
# 2020-01-31                 216040.0
# 2020-02-29                 217182.0
# 2020-03-31                 218346.0

# %%
zip_46220_3B = quandl.get("ZILLOW/Z46220_ZHVI3B")
zip_46220_3B_df = pd.DataFrame(zip_46220_3B)
zip_46220_3B_df1 = zip_46220_3B_df.rename(columns={"Value":"Median Price 3 Bedrooms"})
zip_46220_3B_df1.head()
# Out:
#             Median Price 3 Bedrooms
# Date
# 1996-04-30                 135000.0
# 1996-05-31                 134100.0
# 1996-06-30                 133000.0
# 1996-07-31                 132000.0
# 1996-08-31                 130900.0

# %%
zip_46220_4B = quandl.get("ZILLOW/Z46220_ZHVI4B")
zip_46220_4B_df = pd.DataFrame(zip_46220_4B)
zip_46220_4B_df1 = zip_46220_4B_df.rename(columns={"Value":"Median Price 4 Bedrooms"})
zip_46220_4B_df1.head()
# Out:
#             Median Price 4 Bedrooms
# Date
# 1996-04-30                 162400.0
# 1996-05-31                 163100.0
# 1996-06-30                 163700.0
# 1996-07-31                 164300.0
# 1996-08-31                 165000.0

# %%
zip_46220_5B = quandl.get("ZILLOW/Z46220_ZHVI5B")
zip_46220_5B_df = pd.DataFrame(zip_46220_5B)
zip_46220_5B_df1 = zip_46220_5B_df.rename(columns={"Value":"Median Price 5+ Bedrooms"})
zip_46220_5B_df1.head()
# Out:
#             Median Price 5+ Bedrooms
# Date
# 1996-04-30                  235900.0
# 1996-05-31                  237400.0
# 1996-06-30                  238900.0
# 1996-07-31                  240400.0
# 1996-08-31                  241900.0

# %%
zip_46220_SF = quandl.get("ZILLOW/Z46220_ZHVISF")
zip_46220_SF_df = pd.DataFrame(zip_46220_SF)
zip_46220_SF_df1 = zip_46220_SF_df.rename(columns={"Value":"Median Market Value (Single Family)"})
zip_46220_SF_df1.head()
# Out:
#             Median Market Value (Single Family)
# Date
# 1996-04-30                             136200.0
# 1996-05-31                             135100.0
# 1996-06-30                             133800.0
# 1996-07-31                             132200.0
# 1996-08-31                             130600.0

# %%
zip_46220_median_sale = quandl.get("ZILLOW/Z46220_SALES")
zip_46220_median_sale_df = pd.DataFrame(zip_46220_median_sale)
zip_46220_median_sale_df1 = zip_46220_median_sale_df.rename(columns={"Value":"Sales per Month"})
zip_46220_median_sale_df1.tail()
# Out:
#             Sales per Month
# Date
# 2016-02-29             25.0
# 2016-03-31             49.0
# 2016-04-30             59.0
# 2016-05-31             78.0
# 2016-06-30             37.0

# %%
zip_46220_median_listprice = quandl.get("ZILLOW/Z46220_MLPSF")
zip_46220_median_listprice_df = pd.DataFrame(zip_46220_median_listprice)
zip_46220_median_listprice_df1 = zip_46220_median_listprice_df.rename(columns={"Value":"Median List Price"})
zip_46220_median_listprice_df1.head()
# Out:
#             Median List Price
# Date
# 2010-01-31           174900.0
# 2010-02-28           169900.0
# 2010-03-31           174900.0
# 2010-04-30           179800.0
# 2010-05-31           179900.0

# %%
zip_46220_median_squarefoot = quandl.get("ZILLOW/Z46220_MLPFSF")
zip_46220_median_squarefoot_df = pd.DataFrame(zip_46220_median_squarefoot)
zip_46220_median_squarefoot_df1 = zip_46220_median_squarefoot_df.rename(columns={"Value":"Median List Price per Square Foot"})
zip_46220_median_squarefoot_df1.head()
# Out:
#             Median List Price per Square Foot
# Date
# 2010-01-31                         116.973244
# 2010-02-28                         118.577075
# 2010-03-31                         122.623348
# 2010-04-30                         123.177083
# 2010-05-31                         124.704422

# %%
zip_46220_percent_reduced = quandl.get("ZILLOW/Z46220_MPPRSF")
zip_46220_percent_reduced_df = pd.DataFrame(zip_46220_percent_reduced)
zip_46220_percent_reduced_df1 = zip_46220_percent_reduced_df.rename(columns={"Value":"Median % Reduction"})
zip_46220_percent_reduced_df1.head()
# Out:
#             Median % Reduction
# Date
# 2010-09-30            3.903076
# 2010-10-31            3.573981
# 2010-11-30            4.001921
# 2010-12-31            3.706449
# 2011-01-31            2.904208

# %%
zip_46220_percent_increasing = quandl.get("ZILLOW/Z46220_PHDVAH")
zip_46220_percent_increasing_df = pd.DataFrame(zip_46220_percent_increasing)
zip_46220_percent_increasing_df1 = zip_46220_percent_increasing_df.rename(columns={"Value":"% of Homes Increasing in Value"})
zip_46220_percent_increasing_df1.head()
# Out:
#             % of Homes Increasing in Value
# Date
# 2005-02-28                           14.78
# 2005-03-31                           14.62
# 2005-04-30                           16.84
# 2005-05-31                           12.16
# 2005-06-30                           19.30

# %%
zip_46220_percent_decreasing = quandl.get("ZILLOW/Z46220_PHIVAH")
zip_46220_percent_decreasing_df = pd.DataFrame(zip_46220_percent_decreasing)
zip_46220_percent_decreasing_df1 = zip_46220_percent_decreasing_df.rename(columns={"Value":"% of Homes Decreasing in Value"})
zip_46220_percent_decreasing_df1.head()
# Out:
#             % of Homes Decreasing in Value
# Date
# 2005-02-28                           78.07
# 2005-03-31                           77.71
# 2005-04-30                           74.22
# 2005-05-31                           79.57
# 2005-06-30                           69.83

# %%
zip_46220_percent_listedreduction = quandl.get("ZILLOW/Z46220_PLPRSF")
zip_46220_percent_listedreduction_df = pd.DataFrame(zip_46220_percent_listedreduction)
zip_46220_percent_listedreduction_df1 = zip_46220_percent_listedreduction_df.rename(columns={"Value":"% of Listings with Price Reduction"})
zip_46220_percent_listedreduction_df1.tail()
# Out:
#             % of Listings with Price Reduction
# Date
# 2019-08-31                           23.437500
# 2019-09-30                           24.107143
# 2019-10-31                           23.430962
# 2019-11-30                           17.180617
# 2019-12-31                           16.216216

# %%
dfs = [zip_46220_1B_df1, zip_46220_2B_df1, zip_46220_3B_df1, zip_46220_4B_df1, zip_46220_5B_df1, zip_46220_SF_df1,
      zip_46220_median_sale_df1, zip_46220_median_listprice_df1, zip_46220_median_squarefoot_df1,
      zip_46220_percent_reduced_df1, zip_46220_percent_increasing_df1, zip_46220_percent_decreasing_df1,
      zip_46220_percent_listedreduction_df1]

# %%
#combine dataframes
from functools import reduce
zip46220 = reduce(lambda left,right: pd.merge(left,right,on='Date', how='outer'), dfs)
zip46220.tail()
# Out:
#             Median Price 1 Bedroom  Median Price 2 Bedrooms  \
# Date
# 2019-11-30                172591.0                 215522.0
# 2019-12-31                172684.0                 215573.0
# 2020-01-31                173191.0                 216040.0
# 2020-02-29                174423.0                 217182.0
# 2020-03-31                175273.0                 218346.0
#
#             Median Price 3 Bedrooms  Median Price 4 Bedrooms  \
# Date
# 2019-11-30                 243825.0                 338265.0
# 2019-12-31                 244010.0                 338727.0
# 2020-01-31                 244343.0                 339216.0
# 2020-02-29                 245442.0                 340957.0
# 2020-03-31                 246543.0                 342123.0
#
#             Median Price 5+ Bedrooms  Median Market Value (Single Family)  \
# Date
# 2019-11-30                  475723.0                             246991.0
# ...

# %%
zip46220["Zip_Code"] = '46220'

# %%
zip46220.head()
# Out:
#             Median Price 1 Bedroom  Median Price 2 Bedrooms  \
# Date
# 1996-04-30                113900.0                 116300.0
# 1996-05-31                113700.0                 116100.0
# 1996-06-30                113500.0                 116000.0
# 1996-07-31                113400.0                 115900.0
# 1996-08-31                113100.0                 115700.0
#
#             Median Price 3 Bedrooms  Median Price 4 Bedrooms  \
# Date
# 1996-04-30                 135000.0                 162400.0
# 1996-05-31                 134100.0                 163100.0
# 1996-06-30                 133000.0                 163700.0
# 1996-07-31                 132000.0                 164300.0
# 1996-08-31                 130900.0                 165000.0
#
#             Median Price 5+ Bedrooms  Median Market Value (Single Family)  \
# Date
# 1996-04-30                  235900.0                             136200.0
# ...

# %%
zip46220.to_csv("zip46220.csv")

# %%
#zip = 46220
#practice = f"Zillow/Z{zip}_ZHVI1B"
#print(practice)

# %%
indianapolis_zipcodes = ["46107", "46217", "46218", "46219", "46220","46221", "46222", "46224", "46225", "46226",
                        "46227", "46228", "46229", "46231", "46234", "46235", "46201", "46202", "46203", "46204",
                        "46205", "46208", "46214", "46237", "46239", "46240", "46241", "46250", "46254", "46256",
                        "46259", "46260", "46268", "46278", "46216", "46236", "46183"]

# %%
indianapolis_zipcodes_dataavailable = ["46107", "46217", "46218", "46219", "46220"]

# %%
Indianapolis_Housing_Data = pd.DataFrame()

# %%
for zip in indianapolis_zipcodes:
    dataframe_list = []
    
    try:
        #One Bedroom DataFrame
        one_bedroom_indicator = f"Zillow/Z{zip}_ZHVI1B"
        one_bedroom = quandl.get(one_bedroom_indicator)
        one_bedroom_df = pd.DataFrame(one_bedroom)
        one_bedroom_final = one_bedroom_df.rename(columns={"Value": "Median Price 1 Bedroom"})
        dataframe_list.append(one_bedroom_final)
    except:
        print(one_bedroom_indicator)
    
    try:
        #Two Bedroom DataFrame
        two_bedroom_indicator = f"Zillow/Z{zip}_ZHVI2B"
        two_bedroom = quandl.get(two_bedroom_indicator)
        two_bedroom_df = pd.DataFrame(two_bedroom)
        two_bedroom_final = two_bedroom_df.rename(columns={"Value": "Median Price 2 Bedroom"})
        dataframe_list.append(two_bedroom_final)
    except:
        print(two_bedroom_indicator)
        
    try:
        #Three Bedroom DataFrame
        three_bedroom_indicator = f"Zillow/Z{zip}_ZHVI3B"
        three_bedroom = quandl.get(three_bedroom_indicator)
        three_bedroom_df = pd.DataFrame(three_bedroom)
        three_bedroom_final = three_bedroom_df.rename(columns={"Value": "Median Price 3 Bedroom"})
        dataframe_list.append(three_bedroom_final)
    except:
        print(three_bedroom_indicator)

    try:
        #Four Bedroom DataFrame
        four_bedroom_indicator = f"Zillow/Z{zip}_ZHVI4B"
        four_bedroom = quandl.get(four_bedroom_indicator)
        four_bedroom_df = pd.DataFrame(four_bedroom)
        four_bedroom_final = four_bedroom_df.rename(columns={"Value": "Median Price 4 Bedroom"})
        dataframe_list.append(four_bedroom_final)
    except:
        print(four_bedroom_indicator)
        
    try:
        #Five Bedroom DataFrame
        five_bedroom_indicator = f"Zillow/Z{zip}_ZHVI5B"
        five_bedroom = quandl.get(five_bedroom_indicator)
        five_bedroom_df = pd.DataFrame(five_bedroom)
        five_bedroom_final = five_bedroom_df.rename(columns={"Value": "Median Price 5 Bedroom"})
        dataframe_list.append(five_bedroom_final)
    except:
        print(five_bedroom_indicator)

    try:
        #Median Market Value (Single Family)
        median_market_value_indicator = f"Zillow/Z{zip}_ZHVISF"
        median_market_value = quandl.get(median_market_value_indicator)
        median_market_value_df = pd.DataFrame(median_market_value)
        median_market_value_final = median_market_value_df.rename(columns={"Value":"Median Market Value (Single Family)"})
        dataframe_list.append(median_market_value_final)
    except:
        print(median_market_value_indicator)
        
    try:
        #Sales per Month
        salesPerMonth_indicator = f"Zillow/Z{zip}_SALES"
        salesPerMonth = quandl.get(salesPerMonth_indicator)
        salesPerMonth_df = pd.DataFrame(salesPerMonth)
        salesPerMonth_final = salesPerMonth_df.rename(columns={"Value":"Sales per Month"})
        dataframe_list.append(salesPerMonth_final)
    except:
        print(salesPerMonth_indicator)

    try:
        #Median List Price
        medianListPrice_indicator = f"Zillow/Z{zip}_MLPSF"
        medianListPrice = quandl.get(medianListPrice_indicator)
        medianListPrice_df = pd.DataFrame(medianListPrice)
        medianListPrice_final = medianListPrice_df.rename(columns={"Value":"Median List Price"})
        dataframe_list.append(medianListPrice_final)
    except:
        print(medianListPrice_indicator)

    try:
        #Median List Price per Square Foot
        medianPrice_squareFoot_indicator = f"Zillow/Z{zip}_MLPFSF"
        medianPrice_squareFoot = quandl.get(medianPrice_squareFoot_indicator)
        medianPrice_squareFoot_df = pd.DataFrame(medianPrice_squareFoot)
        medianPrice_squareFoot_final = medianPrice_squareFoot_df.rename(columns={"Value":"Median List Price per Square Foot"})
        dataframe_list.append(medianPrice_squareFoot_final)
    except:
        print(medianPrice_squareFoot_indicator)

    try:
        #Median % Reduction
        percentReduction_indicator = f"Zillow/Z{zip}_MPPRSF"
        percentReduction = quandl.get(percentReduction_indicator)
        percentReduction_df = pd.DataFrame(percentReduction)
        percentReduction_final = percentReduction_df.rename(columns={"Value":"Median % Reduction"})
        dataframe_list.append(percentReduction_final)
    except:
        print(percentReduction_indicator)

    try:
        #Percentage of Homes Increasing in Value
        percentIncreasing_indicator = f"Zillow/Z{zip}_PHDVAH"
        percentIncreasing = quandl.get(percentIncreasing_indicator)
        percentIncreasing_df = pd.DataFrame(percentIncreasing)
        percentIncreasing_final = percentIncreasing_df.rename(columns={"Value":"% of Homes Increasing in Value"})
        dataframe_list.append(percentIncreasing_final)
    except:
        print(percentIncreasing_indicator)

    try:
        #Percentage of Homes Decreasing in Value
        percentDecreasing_indicator = f"Zillow/Z{zip}_PHIVAH"
        percentDecreasing= quandl.get(percentDecreasing_indicator)
        percentDecreasing_df = pd.DataFrame(percentDecreasing)
        percentDecreasing_final = percentDecreasing_df.rename(columns={"Value":"% of Homes Decreasing in Value"})
        dataframe_list.append(percentDecreasing_final)
    except:
        print(percentDecreasing_indicator)

    try:
        #Percentage of Listings with Price Reduction
        percentListedReduction_indicator = f"Zillow/Z{zip}_PLPRSF"
        percentListedReduction= quandl.get(percentListedReduction_indicator)
        percentListedReduction_df = pd.DataFrame(percentListedReduction)
        percentListedReduction_final = percentListedReduction_df.rename(columns={"Value":"% of Listings with Price Reduction"})
        dataframe_list.append(percentListedReduction_final)
    except:
        print(percentListedReduction_indicator)
    
    #Merge DataFrames
    from functools import reduce
    zipData = reduce(lambda left,right: pd.merge(left,right,on='Date', how='outer'), dataframe_list)
    zipData["Zip_Code"] = zip
    zipData.sort_values(by=['Date'], inplace=True)
    
    
    #Add DataFrame for each Zip Code to the final DataFrame
    Indianapolis_Housing_Data = pd.concat([Indianapolis_Housing_Data, zipData])
# Out:
# Zillow/Z46225_MPPRSF
# /Users/allysontalyor/Applications/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:142: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# Zillow/Z46204_ZHVI5B
# Zillow/Z46204_MLPSF
# Zillow/Z46204_MLPFSF
# Zillow/Z46204_MPPRSF
# Zillow/Z46204_PLPRSF
# Zillow/Z46216_ZHVI1B
# Zillow/Z46216_MLPSF
# Zillow/Z46216_MLPFSF
# Zillow/Z46216_MPPRSF
# Zillow/Z46216_PLPRSF
# Zillow/Z46183_ZHVI1B
# Zillow/Z46183_ZHVI5B
# Zillow/Z46183_MLPSF
# Zillow/Z46183_MLPFSF
# Zillow/Z46183_MPPRSF
# Zillow/Z46183_PLPRSF

# %%
#pd.set_option("display.max_rows", None, "display.max_columns", None)
Indianapolis_Housing_Data.head()
# Out:
#             % of Homes Decreasing in Value  % of Homes Increasing in Value  \
# Date
# 1996-04-30                             NaN                             NaN
# 1996-05-31                             NaN                             NaN
# 1996-06-30                             NaN                             NaN
# 1996-07-31                             NaN                             NaN
# 1996-08-31                             NaN                             NaN
#
#             % of Listings with Price Reduction  Median % Reduction  \
# Date
# 1996-04-30                                 NaN                 NaN
# 1996-05-31                                 NaN                 NaN
# 1996-06-30                                 NaN                 NaN
# 1996-07-31                                 NaN                 NaN
# 1996-08-31                                 NaN                 NaN
#
#             Median List Price  Median List Price per Square Foot  \
# Date
# ...

# %%
print(len(Indianapolis_Housing_Data["Zip_Code"]))
# Out:
# 10399

# %%
zip46225 = Indianapolis_Housing_Data.loc[Indianapolis_Housing_Data["Zip_Code"] == "46225"]
zip46225.tail()
# Out:
#             % of Homes Decreasing in Value  % of Homes Increasing in Value  \
# Date
# 2019-11-30                             NaN                             NaN
# 2019-12-31                             NaN                             NaN
# 2020-01-31                             NaN                             NaN
# 2020-02-29                             NaN                             NaN
# 2020-03-31                             NaN                             NaN
#
#             % of Listings with Price Reduction  Median % Reduction  \
# Date
# 2019-11-30                           21.176471                 NaN
# 2019-12-31                           15.277778                 NaN
# 2020-01-31                                 NaN                 NaN
# 2020-02-29                                 NaN                 NaN
# 2020-03-31                                 NaN                 NaN
#
#             Median List Price  Median List Price per Square Foot  \
# Date
# ...

# %%
zip46204 = Indianapolis_Housing_Data.loc[Indianapolis_Housing_Data["Zip_Code"] == "46204"]
zip46204.tail()
# Out:
#             % of Homes Decreasing in Value  % of Homes Increasing in Value  \
# Date
# 2019-11-30                             NaN                             NaN
# 2019-12-31                             NaN                             NaN
# 2020-01-31                             NaN                             NaN
# 2020-02-29                             NaN                             NaN
# 2020-03-31                             NaN                             NaN
#
#             % of Listings with Price Reduction  Median % Reduction  \
# Date
# 2019-11-30                                 NaN                 NaN
# 2019-12-31                                 NaN                 NaN
# 2020-01-31                                 NaN                 NaN
# 2020-02-29                                 NaN                 NaN
# 2020-03-31                                 NaN                 NaN
#
#             Median List Price  Median List Price per Square Foot  \
# Date
# ...

# %%
zip46216 = Indianapolis_Housing_Data.loc[Indianapolis_Housing_Data["Zip_Code"] == "46216"]
zip46216.tail()
# Out:
#             % of Homes Decreasing in Value  % of Homes Increasing in Value  \
# Date
# 2019-11-30                             NaN                             NaN
# 2019-12-31                             NaN                             NaN
# 2020-01-31                             NaN                             NaN
# 2020-02-29                             NaN                             NaN
# 2020-03-31                             NaN                             NaN
#
#             % of Listings with Price Reduction  Median % Reduction  \
# Date
# 2019-11-30                                 NaN                 NaN
# 2019-12-31                                 NaN                 NaN
# 2020-01-31                                 NaN                 NaN
# 2020-02-29                                 NaN                 NaN
# 2020-03-31                                 NaN                 NaN
#
#             Median List Price  Median List Price per Square Foot  \
# Date
# ...

# %%
zip46220 = Indianapolis_Housing_Data.loc[Indianapolis_Housing_Data["Zip_Code"] == "46220"]
zip46220.tail()
# Out:
#             % of Homes Decreasing in Value  % of Homes Increasing in Value  \
# Date
# 2019-11-30                             NaN                             NaN
# 2019-12-31                             NaN                             NaN
# 2020-01-31                             NaN                             NaN
# 2020-02-29                             NaN                             NaN
# 2020-03-31                             NaN                             NaN
#
#             % of Listings with Price Reduction  Median % Reduction  \
# Date
# 2019-11-30                           17.180617            2.723312
# 2019-12-31                           16.216216            3.006368
# 2020-01-31                                 NaN                 NaN
# 2020-02-29                                 NaN                 NaN
# 2020-03-31                                 NaN                 NaN
#
#             Median List Price  Median List Price per Square Foot  \
# Date
# ...

# %%
Indianapolis_Housing_Data.to_csv("Indianapolis_Housing_Data.csv")

# %%
Modified_Housing = Indianapolis_Housing_Data.copy()
Modified_Housing["Date"] = Modified_Housing.index
Modified_Housing.head()
#Modified_Housing = Modified_Housing['Date'].split("-", expand=True)
# Out:
#             % of Homes Decreasing in Value  % of Homes Increasing in Value  \
# Date
# 1996-04-30                             NaN                             NaN
# 1996-05-31                             NaN                             NaN
# 1996-06-30                             NaN                             NaN
# 1996-07-31                             NaN                             NaN
# 1996-08-31                             NaN                             NaN
#
#             % of Listings with Price Reduction  Median % Reduction  \
# Date
# 1996-04-30                                 NaN                 NaN
# 1996-05-31                                 NaN                 NaN
# 1996-06-30                                 NaN                 NaN
# 1996-07-31                                 NaN                 NaN
# 1996-08-31                                 NaN                 NaN
#
#             Median List Price  Median List Price per Square Foot  \
# Date
# ...

# %%
Modified_Housing = Modified_Housing["Date"].split("-", expand=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-256-6c2888f695bc> in <module>
# ----> 1 Modified_Housing = Modified_Housing["Date"].split("-", expand=True)
#
# ~/Applications/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'split'

# %%
#Modified_Housing.reset_index()
#Modified_Housing["Date"].astype(str)
Modified_Housing.Date.str.split("-",expand=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-262-79d27d683777> in <module>
#       1 #Modified_Housing.reset_index()
#       2 Modified_Housing["Date"].astype(str)
# ----> 3 Modified_Housing.Date.str.split("-",expand=True)
#
# ~/Applications/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5173             or name in self._accessors
#    5174         ):
# -> 5175             return object.__getattribute__(self, name)
#    5176         else:
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/Applications/anaconda3/envs/PythonData/lib/python3.7/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     173             # we're accessing the attribute of the class, i.e., Dataset.geo
#     174             return self._accessor
# ...

# %%
#Modified_Housing["Date"].astype(str)
Modified_Housing.dtypes
# Out:
# % of Homes Decreasing in Value                float64
# % of Homes Increasing in Value                float64
# % of Listings with Price Reduction            float64
# Median % Reduction                            float64
# Median List Price                             float64
# Median List Price per Square Foot             float64
# Median Market Value (Single Family)           float64
# Median Price 1 Bedroom                        float64
# Median Price 2 Bedroom                        float64
# Median Price 3 Bedroom                        float64
# Median Price 4 Bedroom                        float64
# Median Price 5 Bedroom                        float64
# Sales per Month                               float64
# Zip_Code                                       object
# Date                                   datetime64[ns]
# dtype: object

# %%
Modified_Housing.dtypes
# Out:
# % of Homes Decreasing in Value                float64
# % of Homes Increasing in Value                float64
# % of Listings with Price Reduction            float64
# Median % Reduction                            float64
# Median List Price                             float64
# Median List Price per Square Foot             float64
# Median Market Value (Single Family)           float64
# Median Price 1 Bedroom                        float64
# Median Price 2 Bedroom                        float64
# Median Price 3 Bedroom                        float64
# Median Price 4 Bedroom                        float64
# Median Price 5 Bedroom                        float64
# Sales per Month                               float64
# Zip_Code                                       object
# Date                                   datetime64[ns]
# dtype: object

# %%
Modified_Housing.to_csv("Modified_Housing.csv")

# %%
Housing_Data = pd.read_csv("Modified_Housing.csv", dtype={"Date": str})
Housing_Data.dtypes
# Out:
# Date                                    object
# % of Homes Decreasing in Value         float64
# % of Homes Increasing in Value         float64
# % of Listings with Price Reduction     float64
# Median % Reduction                     float64
# Median List Price                      float64
# Median List Price per Square Foot      float64
# Median Market Value (Single Family)    float64
# Median Price 1 Bedroom                 float64
# Median Price 2 Bedroom                 float64
# Median Price 3 Bedroom                 float64
# Median Price 4 Bedroom                 float64
# Median Price 5 Bedroom                 float64
# Sales per Month                        float64
# Zip_Code                                 int64
# Date.1                                  object
# dtype: object

# %%
Housing_Data.head()
# Out:
#          Date  % of Homes Decreasing in Value  % of Homes Increasing in Value  \
# 0  1996-04-30                             NaN                             NaN
# 1  1996-05-31                             NaN                             NaN
# 2  1996-06-30                             NaN                             NaN
# 3  1996-07-31                             NaN                             NaN
# 4  1996-08-31                             NaN                             NaN
#
#    % of Listings with Price Reduction  Median % Reduction  Median List Price  \
# 0                                 NaN                 NaN                NaN
# 1                                 NaN                 NaN                NaN
# 2                                 NaN                 NaN                NaN
# 3                                 NaN                 NaN                NaN
# 4                                 NaN                 NaN                NaN
#
# ...

# %%
Housing_Data[["Year","Month","Day"]] = Housing_Data.Date.str.split("-",expand=True)

# %%
Housing_Data.head()
Housing_Data.to_csv("Indianapolis_Housing.csv")

# %%
Housing_Data_January = Housing_Data.loc[Housing_Data["Month"] == "01"]
Housing_Data_January.head()
# Out:
#           Date  % of Homes Decreasing in Value  \
# 9   1997-01-31                             NaN
# 21  1998-01-31                             NaN
# 33  1999-01-31                             NaN
# 45  2000-01-31                             NaN
# 57  2001-01-31                             NaN
#
#     % of Homes Increasing in Value  % of Listings with Price Reduction  \
# 9                              NaN                                 NaN
# 21                             NaN                                 NaN
# 33                             NaN                                 NaN
# 45                             NaN                                 NaN
# 57                             NaN                                 NaN
#
#     Median % Reduction  Median List Price  Median List Price per Square Foot  \
# 9                  NaN                NaN                                NaN
# 21                 NaN                NaN                                NaN
# ...

# %%
Dropped_Housing = Housing_Data_January.dropna()

# %%
print(len(Housing_Data_January.Date))
print(len(Dropped_Housing.Date))
# Out:
# 869
# 150

# %%
#for one county 46220
zip46220_january = Housing_Data_January.loc[Housing_Data_January["Zip_Code"] == 46220]
zip46220_january
# Out:
#             Date  % of Homes Decreasing in Value  \
# 1117  1997-01-31                             NaN
# 1129  1998-01-31                             NaN
# 1141  1999-01-31                             NaN
# 1153  2000-01-31                             NaN
# 1165  2001-01-31                             NaN
# 1177  2002-01-31                             NaN
# 1189  2003-01-31                             NaN
# 1201  2004-01-31                             NaN
# 1213  2005-01-31                             NaN
# 1225  2006-01-31                           72.44
# 1237  2007-01-31                           67.38
# 1249  2008-01-31                           50.06
# 1261  2009-01-31                           19.30
# 1273  2010-01-31                           16.16
# 1285  2011-01-31                           34.91
# 1297  2012-01-31                           56.48
# 1309  2013-01-31                           53.20
# 1321  2014-01-31                           72.10
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
plt.plot(zip46220_january["Year"], zip46220_january["Median Market Value (Single Family)"])

# %%
price_per_square_foot = zip46220_january["Median List Price per Square Foot"].to_list()
sliced_price_per_square_foot = price_per_square_foot[13:23]
#sliced_price_per_square_foot
years = zip46220_january["Year"].to_list()
sliced_years = years[13:23]
sliced_years
# Out:
# ['2010',
#  '2011',
#  '2012',
#  '2013',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019']

# %%
plt.plot(sliced_years, sliced_price_per_square_foot)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#zip46220_january.head(150)
January_46220 = zip46220_january[["Date", "Zip_Code","Median List Price", "Median List Price per Square Foot", 
                                  "Median Market Value (Single Family)", "Median Price 1 Bedroom",
                                 "Median Price 2 Bedroom", "Median Price 3 Bedroom", "Median Price 4 Bedroom",
                                 "Median Price 5 Bedroom", "Year", "Month"]]

# %%
January_46220.head()
# Out:
#             Date  Zip_Code  Median List Price  \
# 1117  1997-01-31     46220                NaN
# 1129  1998-01-31     46220                NaN
# 1141  1999-01-31     46220                NaN
# 1153  2000-01-31     46220                NaN
# 1165  2001-01-31     46220                NaN
#
#       Median List Price per Square Foot  Median Market Value (Single Family)  \
# 1117                                NaN                             126400.0
# 1129                                NaN                             151900.0
# 1141                                NaN                             150600.0
# 1153                                NaN                             154967.0
# 1165                                NaN                             155566.0
#
#       Median Price 1 Bedroom  Median Price 2 Bedroom  Median Price 3 Bedroom  \
# 1117                112900.0                116300.0                129200.0
# ...

# %%
January_46220['Year'] = pd.to_numeric(January_46220['Year'])
# Out:
# /Users/allysontalyor/Applications/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
January_46220["Year_Integer"] = January_46220["Year"] - 1996
January_46220.tail()
# Out:
# /Users/allysontalyor/Applications/anaconda3/envs/PythonData/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#             Date  Zip_Code  Median List Price  \
# 1345  2016-01-31     46220           195000.0
# 1357  2017-01-31     46220           199000.0
# 1369  2018-01-31     46220           249950.0
# 1381  2019-01-31     46220           239900.0
# 1393  2020-01-31     46220                NaN
#
#       Median List Price per Square Foot  Median Market Value (Single Family)  \
# 1345                         139.705882                             195857.0
# 1357                         153.180804                             206856.0
# ...

# %%
print(len(January_46220.Year))
# Out:
# 24

# %% [markdown]
# **Starting Machine Learning Predictor for January, zip code 46220 to fill in data for Median List Price per SqFt**

# %%
#Limit dataframe to those dates that are available for Median List Price per SqFt
MLPSqFt_46220 = January_46220.loc["January_46220"]
#Define X and y
X = January_46220[["gender", "age", "size"]]
y = brain["weight"].values.reshape(-1, 1)
print(X.shape, y.shape)
