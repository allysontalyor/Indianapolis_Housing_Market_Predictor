# %%
import csv
import pandas as pd

# %%
housing_df = pd.read_csv("Indianapolis_Housing_Data.csv")
housing_df.head()
# Out:
#          Date  % of Homes Decreasing in Value  % of Homes Increasing in Value  \
# 0  1996-04-30                             NaN                             NaN
# 1  1996-05-31                             NaN                             NaN
# 2  1996-06-30                             NaN                             NaN
# 3  1996-07-31                             NaN                             NaN
# 4  1996-08-31                             NaN                             NaN
#
#    % of Listings with Price Reduction  Median % Reduction  Median List Price  \
# 0                                 NaN                 NaN                NaN
# 1                                 NaN                 NaN                NaN
# 2                                 NaN                 NaN                NaN
# 3                                 NaN                 NaN                NaN
# 4                                 NaN                 NaN                NaN
#
# ...

# %%
housing_df.dtypes
# Out:
# Date                                    object
# % of Homes Decreasing in Value         float64
# % of Homes Increasing in Value         float64
# % of Listings with Price Reduction     float64
# Median % Reduction                     float64
# Median List Price                      float64
# Median List Price per Square Foot      float64
# Median Market Value (Single Family)    float64
# Median Price 1 Bedroom                 float64
# Median Price 2 Bedroom                 float64
# Median Price 3 Bedroom                 float64
# Median Price 4 Bedroom                 float64
# Median Price 5 Bedroom                 float64
# Sales per Month                        float64
# Zip_Code                                 int64
# dtype: object

# %%
housing_df_nonan = housing_df.dropna()

# %%
housing_df_nonan.Zip_Code.unique()
# Out:
# array([46107, 46217, 46218, 46219, 46220, 46221, 46222, 46224, 46226,
#        46227, 46228, 46229, 46231, 46234, 46235, 46202, 46205, 46214,
#        46237, 46239, 46240, 46241, 46254, 46256, 46259, 46260, 46268,
#        46236])

# %%
housing_df_nonan.count()
# Out:
# Date                                   1747
# % of Homes Decreasing in Value         1747
# % of Homes Increasing in Value         1747
# % of Listings with Price Reduction     1747
# Median % Reduction                     1747
# Median List Price                      1747
# Median List Price per Square Foot      1747
# Median Market Value (Single Family)    1747
# Median Price 1 Bedroom                 1747
# Median Price 2 Bedroom                 1747
# Median Price 3 Bedroom                 1747
# Median Price 4 Bedroom                 1747
# Median Price 5 Bedroom                 1747
# Sales per Month                        1747
# Zip_Code                               1747
# dtype: int64

# %%
housing_df_nonan.head()
# Out:
#            Date  % of Homes Decreasing in Value  \
# 173  2010-09-30                           12.94
# 174  2010-10-31                           14.25
# 175  2010-11-30                           20.77
# 176  2010-12-31                           22.06
# 177  2011-01-31                           24.30
#
#      % of Homes Increasing in Value  % of Listings with Price Reduction  \
# 173                           77.61                           15.254237
# 174                           76.32                           11.111111
# 175                           69.23                           11.278195
# 176                           68.58                           16.000000
# 177                           66.09                           19.130435
#
#      Median % Reduction  Median List Price  Median List Price per Square Foot  \
# 173            4.766444            85000.0                          72.815534
# 174            5.889282            85000.0                          72.410148
# ...

# %%
housing_df_nonan.Date.unique()
# Out:
# array(['2010-09-30', '2010-10-31', '2010-11-30', '2010-12-31',
#        '2011-01-31', '2011-02-28', '2011-03-31', '2011-04-30',
#        '2011-05-31', '2011-06-30', '2011-07-31', '2011-08-31',
#        '2011-09-30', '2011-10-31', '2011-11-30', '2011-12-31',
#        '2012-01-31', '2012-02-29', '2012-03-31', '2012-04-30',
#        '2012-05-31', '2012-06-30', '2012-07-31', '2012-08-31',
#        '2012-09-30', '2012-10-31', '2012-11-30', '2012-12-31',
#        '2013-01-31', '2013-02-28', '2013-03-31', '2013-04-30',
#        '2013-05-31', '2013-06-30', '2013-07-31', '2013-08-31',
#        '2013-09-30', '2013-10-31', '2013-11-30', '2013-12-31',
#        '2014-01-31', '2014-02-28', '2014-03-31', '2014-04-30',
#        '2014-05-31', '2014-06-30', '2014-07-31', '2014-08-31',
#        '2014-09-30', '2014-10-31', '2014-11-30', '2014-12-31',
#        '2015-01-31', '2015-02-28', '2015-03-31', '2015-04-30',
#        '2015-05-31', '2015-06-30', '2015-07-31', '2015-08-31',
# ...

# %%
housing_df_nonan.Date.astype(str)
# Out:
# 173      2010-09-30
# 174      2010-10-31
# 175      2010-11-30
# 176      2010-12-31
# 177      2011-01-31
#             ...
# 10101    2016-02-29
# 10102    2016-03-31
# 10103    2016-04-30
# 10104    2016-05-31
# 10105    2016-06-30
# Name: Date, Length: 1747, dtype: object

# %%
housing_df_nonan.dtypes
# Out:
# Date                                    object
# % of Homes Decreasing in Value         float64
# % of Homes Increasing in Value         float64
# % of Listings with Price Reduction     float64
# Median % Reduction                     float64
# Median List Price                      float64
# Median List Price per Square Foot      float64
# Median Market Value (Single Family)    float64
# Median Price 1 Bedroom                 float64
# Median Price 2 Bedroom                 float64
# Median Price 3 Bedroom                 float64
# Median Price 4 Bedroom                 float64
# Median Price 5 Bedroom                 float64
# Sales per Month                        float64
# Zip_Code                                 int64
# Month                                   object
# dtype: object

# %%
housing_df_month = housing_df_nonan.Date.str.split('-', expand=True)

# %%
housing_df_month.head()
# Out:
#         0   1   2
# 173  2010  09  30
# 174  2010  10  31
# 175  2010  11  30
# 176  2010  12  31
# 177  2011  01  31

# %%
housing_df_nonan['Month'] = housing_df_nonan.Date.apply(lambda x: x[5:7])
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
housing_df_nonan.count()
# Out:
# Date                                   1747
# % of Homes Decreasing in Value         1747
# % of Homes Increasing in Value         1747
# % of Listings with Price Reduction     1747
# Median % Reduction                     1747
# Median List Price                      1747
# Median List Price per Square Foot      1747
# Median Market Value (Single Family)    1747
# Median Price 1 Bedroom                 1747
# Median Price 2 Bedroom                 1747
# Median Price 3 Bedroom                 1747
# Median Price 4 Bedroom                 1747
# Median Price 5 Bedroom                 1747
# Sales per Month                        1747
# Zip_Code                               1747
# Month                                  1747
# dtype: int64

# %%
housing_df_nonan.to_csv('indy_nonan_housing_data.csv')

# %%
housing_df_nonan_12 = housing_df_nonan.loc[housing_df_nonan['Month'] == '12']

# %%
housing_df_nonan_12
# Out:
#              Date  % of Homes Decreasing in Value  \
# 176    2010-12-31                           22.06
# 188    2011-12-31                           18.11
# 200    2012-12-31                           77.21
# 212    2013-12-31                           66.99
# 224    2014-12-31                           34.80
# ...           ...                             ...
# 10051  2011-12-31                           62.66
# 10063  2012-12-31                           60.05
# 10075  2013-12-31                           67.87
# 10087  2014-12-31                           23.80
# 10099  2015-12-31                            7.48
#
#        % of Homes Increasing in Value  % of Listings with Price Reduction  \
# 176                             68.58                           16.000000
# 188                             78.03                            7.692308
# 200                             18.03                           13.235294
# ...

# %%
import matplotlib.pyplot as plt
X = housing_df_nonan_12.loc['Median Market Value (Single Family)'].values.reshape(-1, 1)
y = housing_df_nonan_12.score.values.reshape(-1, 1)
plt.scatter(X, y)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'Median Market Value (Single Family)'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-97d5c2470b15> in <module>
#       1 import matplotlib.pyplot as plt
# ...

# %%
housing_df_nonan_11 = housing_df_nonan.loc[housing_df_nonan['Month'] == '11']

# %%
housing_df_nonan_11.count()
# Out:
# Date                                   147
# % of Homes Decreasing in Value         147
# % of Homes Increasing in Value         147
# % of Listings with Price Reduction     147
# Median % Reduction                     147
# Median List Price                      147
# Median List Price per Square Foot      147
# Median Market Value (Single Family)    147
# Median Price 1 Bedroom                 147
# Median Price 2 Bedroom                 147
# Median Price 3 Bedroom                 147
# Median Price 4 Bedroom                 147
# Median Price 5 Bedroom                 147
# Sales per Month                        147
# Zip_Code                               147
# Month                                  147
# dtype: int64

# %%
housing_df_nonan_10 = housing_df_nonan.loc[housing_df_nonan['Month'] == '10']

# %%
housing_df_nonan_09 = housing_df_nonan.loc[housing_df_nonan['Month'] == '09']

# %%
housing_df_nonan_08 = housing_df_nonan.loc[housing_df_nonan['Month'] == '08']

# %%
housing_df_nonan_07 = housing_df_nonan.loc[housing_df_nonan['Month'] == '07']

# %%
housing_df_nonan_06 = housing_df_nonan.loc[housing_df_nonan['Month'] == '06']

# %%
housing_df_nonan_05 = housing_df_nonan.loc[housing_df_nonan['Month'] == '05']

# %%
housing_df_nonan_04 = housing_df_nonan.loc[housing_df_nonan['Month'] == '04']
housing_df_nonan_03 = housing_df_nonan.loc[housing_df_nonan['Month'] == '03']
housing_df_nonan_02 = housing_df_nonan.loc[housing_df_nonan['Month'] == '02']

# %%
housing_df_nonan_02.head()
# Out:
#            Date  % of Homes Decreasing in Value  \
# 178  2011-02-28                           21.79
# 190  2012-02-29                           33.11
# 202  2013-02-28                           63.63
# 214  2014-02-28                           77.04
# 226  2015-02-28                           38.53
#
#      % of Homes Increasing in Value  % of Listings with Price Reduction  \
# 178                           69.28                           16.216216
# 190                           62.41                           11.111111
# 202                           26.22                            6.153846
# 214                           17.31                           11.688312
# 226                           56.74                           15.789474
#
#      Median % Reduction  Median List Price  Median List Price per Square Foot  \
# 178            7.702195            79450.0                          70.393375
# 190            4.955005            70000.0                          67.710212
# ...

# %%
import pickle
housing_df_nonan_02.to_pickle("housing_df_nonan_02.pkl")

# %%
housing_df_nonan_feb = pd.read_pickle('housing_df_nonan_02.pkl')

# %%
housing_df_nonan_feb = housing_df_nonan_feb.reset_index(drop=True)

# %%
housing_df_nonan_feb.head()
# Out:
#          Date  % of Homes Decreasing in Value  % of Homes Increasing in Value  \
# 0  2011-02-28                           21.79                           69.28
# 1  2012-02-29                           33.11                           62.41
# 2  2013-02-28                           63.63                           26.22
# 3  2014-02-28                           77.04                           17.31
# 4  2015-02-28                           38.53                           56.74
#
#    % of Listings with Price Reduction  Median % Reduction  Median List Price  \
# 0                           16.216216            7.702195            79450.0
# 1                           11.111111            4.955005            70000.0
# 2                            6.153846            9.283108            78000.0
# 3                           11.688312            2.657501            88000.0
# 4                           15.789474            3.924557            92500.0
#
# ...

# %%
housing_df_nonan_feb.to_json('housing_df_nonan_feb.json')
